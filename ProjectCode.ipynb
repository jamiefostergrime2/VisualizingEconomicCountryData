# %%
# PHASE 1: SETUP & DATA LOADING
# ==========================================

# 1. Required Imports
import pandas as pd
import altair as alt
import numpy as np

# 2. Define File Path
# ------------------------------------------
# CURRENT SETUP (For working on your PC now):
# We use a "raw" string (r'...') to handle the backslashes in Windows paths correctly.
file_path = r'C:\Users\Cameron\Downloads\country_economics_data.csv'

# SUBMISSION SETUP (Important for Dec 4th):
# When you submit, move the csv to the same folder as this script and use this instead:
# file_path = 'country_economics_data.csv'

# 3. Load the Data
# ------------------------------------------
try:
    df = pd.read_csv(file_path)
    print("✅ Data loaded successfully!")
    print(f"Shape: {df.shape[0]} rows, {df.shape[1]} columns")

except FileNotFoundError:
    print(f"❌ Error: The file was not found at {file_path}")
    print("Please check the path or move the CSV to the script folder.")
# Out:
# ✅ Data loaded successfully!
# Shape: 173 rows, 21 columns
#
# --- First 5 Rows ---
#           Name  ID Abbreviation        Currency       Capital   Languages  \
# 0  Afghanistan   4           AF  Afghan afghani         Kabul        Dari
# 1      Albania   8           AL    Albanian lek        Tirana    Albanian
# 2      Algeria  12           DZ  Algerian dinar       Algiers      Arabic
# 3       Angola  24           AO  Angolan kwanza        Luanda  Portuguese
# 4    Argentina  32           AR  Argentine peso  Buenos Aires      Guaran
#
#    Latitude  Longitude       Area  Population  ...         Subregion  \
# 0      33.0       65.0   652230.0       35.70  ...     Southern Asia
# 1      41.0       20.0    28748.0        2.36  ...  Southeast Europe
# 2      28.0        3.0  2381741.0       46.81  ...   Northern Africa
# 3     -12.5       18.5  1246700.0       35.12  ...     Middle Africa
# 4     -34.0      -64.0  2780400.0       47.07  ...     South America
#
#                                              Borders  GDP  GDP Growth  \
# 0         ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN']   17         NaN
# 1                       ['MNE', 'GRC', 'MKD', 'UNK']   27         0.7
# 2  ['TUN', 'LBY', 'NER', 'ESH', 'MRT', 'MLI', 'MAR']  264        18.6
# 3                       ['COG', 'COD', 'ZMB', 'NAM']   80         2.3
# 4                ['BOL', 'BRA', 'CHL', 'PRY', 'URY']  633         0.8
#
#    Interest Rate  Inflation Rate  Jobless Rate  Gov. Budget  Debt/GDP  \
# 0          14.94            0.20         13.30        -4.80       8.3
# 1           2.50            2.50          8.70        -0.70      54.7
# 2           3.00           -0.22         11.43        -9.30      46.2
# 3          19.50           19.48         29.40        -1.50      58.2
# 4          29.00           36.60          7.90        -4.37      83.2
#
#    Current Account
# 0            -17.3
# 1             -2.4
# 2              1.3
# 3              5.4
# 4              0.6
#
# [5 rows x 21 columns]
#
# --- Column Names ---
# ['Name', 'ID', 'Abbreviation', 'Currency', 'Capital', 'Languages', 'Latitude', 'Longitude', 'Area', 'Population', 'Region', 'Subregion', 'Borders', 'GDP', 'GDP Growth', 'Interest Rate', 'Inflation Rate', 'Jobless Rate', 'Gov. Budget', 'Debt/GDP', 'Current Account']
#
# --- Missing Values Check ---
# Abbreviation        1
# Capital             1
# Borders            24
# GDP Growth         72
# Interest Rate      11
# Inflation Rate      1
# Jobless Rate        2
# Gov. Budget         7
# Debt/GDP            8
# Current Account     6
# dtype: int64

# %%
# 4. Initial Inspection (Task 1.1 Requirement)
# ------------------------------------------
# Display the first 5 rows to verify data looks correct
print("\n--- First 5 Rows ---")
display(df.head(10))
#display(df.head()) if 'display' in locals() else print(df.head())

# Display column names to help select your 7 attributes
print("\n--- Column Names ---")
print(list(df.columns))

# Check for missing values (NaNs) immediately
print("\n--- Missing Values Check ---")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# --- First 5 Rows ---
#           Name  ID Abbreviation           Currency       Capital    Languages  \
# 0  Afghanistan   4           AF     Afghan afghani         Kabul         Dari
# 1      Albania   8           AL       Albanian lek        Tirana     Albanian
# 2      Algeria  12           DZ     Algerian dinar       Algiers       Arabic
# 3       Angola  24           AO     Angolan kwanza        Luanda   Portuguese
# 4    Argentina  32           AR     Argentine peso  Buenos Aires       Guaran
# 5      Armenia  51           AM      Armenian dram       Yerevan     Armenian
# 6    Australia  36           AU  Australian dollar      Canberra      English
# 7      Austria  40           AT               Euro        Vienna       German
# 8   Azerbaijan  31           AZ  Azerbaijani manat          Baku  Azerbaijani
# 9      Bahamas  44           BS    Bahamian dollar        Nassau      English
#
#     Latitude   Longitude       Area  Population  ...  \
# 0  33.000000   65.000000   652230.0       35.70  ...
# 1  41.000000   20.000000    28748.0        2.36  ...
# 2  28.000000    3.000000  2381741.0       46.81  ...
# 3 -12.500000   18.500000  1246700.0       35.12  ...
# 4 -34.000000  -64.000000  2780400.0       47.07  ...
# 5  40.000000   45.000000    29743.0        2.99  ...
# 6 -27.000000  133.000000  7692024.0       27.40  ...
# 7  47.333333   13.333333    83871.0        9.20  ...
# 8  40.500000   47.500000    86600.0       10.18  ...
# 9  25.034300  -77.396300    13943.0        0.41  ...
#
#                    Subregion  \
# 0              Southern Asia
# 1           Southeast Europe
# 2            Northern Africa
# 3              Middle Africa
# 4              South America
# 5               Western Asia
# 6  Australia and New Zealand
# 7             Central Europe
# 8               Western Asia
# 9                  Caribbean
#
#                                              Borders   GDP  GDP Growth  \
# 0         ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN']    17         NaN
# 1                       ['MNE', 'GRC', 'MKD', 'UNK']    27         0.7
# 2  ['TUN', 'LBY', 'NER', 'ESH', 'MRT', 'MLI', 'MAR']   264        18.6
# 3                       ['COG', 'COD', 'ZMB', 'NAM']    80         2.3
# 4                ['BOL', 'BRA', 'CHL', 'PRY', 'URY']   633         0.8
# 5                       ['AZE', 'GEO', 'IRN', 'TUR']    26         NaN
# 6                                                NaN  1752         0.2
# 7  ['CZE', 'DEU', 'HUN', 'ITA', 'LIE', 'SVK', 'SV...   522         0.1
# 8                ['ARM', 'GEO', 'IRN', 'RUS', 'TUR']    74         NaN
# 9                                                NaN    16         NaN
#
#    Interest Rate  Inflation Rate  Jobless Rate  Gov. Budget  Debt/GDP  \
# 0          14.94            0.20         13.30        -4.80       8.3
# 1           2.50            2.50          8.70        -0.70      54.7
# 2           3.00           -0.22         11.43        -9.30      46.2
# 3          19.50           19.48         29.40        -1.50      58.2
# 4          29.00           36.60          7.90        -4.37      83.2
# 5           6.75            3.40         13.90        -3.15      50.3
# 6           3.60            2.10          4.20         0.60      43.8
# 7           2.15            3.60          6.70        -4.70      81.8
# 8           7.00            5.00          5.30        -0.40      20.9
# 9           4.00           -0.40          9.40        -1.30      81.5
#
#    Current Account
# 0            -17.3
# 1             -2.4
# 2              1.3
# 3              5.4
# 4              0.6
# 5              2.8
# 6             -2.1
# 7              2.4
# 8              6.3
# 9             -7.9
#
# [10 rows x 21 columns]
# --- Column Names ---
# ['Name', 'ID', 'Abbreviation', 'Currency', 'Capital', 'Languages', 'Latitude', 'Longitude', 'Area', 'Population', 'Region', 'Subregion', 'Borders', 'GDP', 'GDP Growth', 'Interest Rate', 'Inflation Rate', 'Jobless Rate', 'Gov. Budget', 'Debt/GDP', 'Current Account']
#
# --- Missing Values Check ---
# Abbreviation        1
# Capital             1
# Borders            24
# GDP Growth         72
# Interest Rate      11
# Inflation Rate      1
# Jobless Rate        2
# Gov. Budget         7
# Debt/GDP            8
# Current Account     6
# dtype: int64
